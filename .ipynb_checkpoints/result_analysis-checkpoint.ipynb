# %%
import pickle
import sys
from simulation import Simulation
from os import listdir
from os.path import isfile, join
import matplotlib.pyplot as plt

# %%
def get_task_results(mypath):
    onlyfiles = [f for f in listdir(mypath) if isfile(join(mypath, f))]
    if '.DS_Store' in onlyfiles:
        onlyfiles.remove('.DS_Store')
    sorted = onlyfiles.sort(key=lambda x:int(x.split('_')[1]))
    onlyfiles.sort(key=lambda x:int(x.split('_')[1]))
    results = []
    for i in onlyfiles:
        results.append(pickle.load(open(join(mypath,i),'rb')))
    return results

# %%
rtrl_results = get_task_results(mypath ='../cluster_results/rtrl_test/')

# %%
fig, axs = plt.subplots(2, 2,figsize=(20,10))

for r in rtrl_results:
    avg_loss = r['average_loss']

    if r['config']['lr'] == 0.1:
        legend = 'units{}_lr{}'.format(r['config']['units'],r['config']['lr'])
        axs[0, 0].plot(avg_loss, label =legend)
    axs[0, 0].legend()
    axs[0, 0].set_ylim(0.4,0.8)
    axs[0, 0].set_title('RTRL LSTM Average Loss')
    
    if r['config']['lr'] == 0.01:
        legend = 'units{}_lr{}'.format(r['config']['units'],r['config']['lr'])
        axs[0, 1].plot(avg_loss,label = legend)
    axs[0, 1].legend()
    axs[0, 1].set_ylim(0.4,0.8)
    axs[0, 1].set_title('RTRL LSTM Average Loss')

    if r['config']['lr'] == 0.001:
        legend = 'units{}_lr{}'.format(r['config']['units'],r['config']['lr'])
        axs[1, 0].plot(avg_loss,label=legend)        
    axs[1, 0].legend()
    axs[1, 0].set_ylim(0.4,0.8)
    axs[1, 0].set_title('RTRL LSTM Average Loss')

    if r['config']['lr'] == 0.0001:
        legend = 'units{}_lr{}'.format(r['config']['units'],r['config']['lr'])
        axs[1, 1].plot(avg_loss,label =legend)       
    axs[1, 1].legend()
    axs[1, 1].set_ylim(0.4,0.8)
    axs[1, 1].set_title('RTRL LSTM Average Loss')

    print(min(avg_loss),legend)
# Out:
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# 0.5123537138237984 units8_lr0.1
# 0.48525035828180524 units8_lr0.01
# 0.48399476702747146 units8_lr0.001
# 0.58056438313172 units8_lr0.0001
# 0.4696077705369018 units16_lr0.1
# 0.45817818966804275 units16_lr0.01
# 0.46246268131717144 units16_lr0.001
# 0.5739633132386046 units16_lr0.0001
# 0.45821640581484957 units32_lr0.1
# 0.4551494789559253 units32_lr0.01
# 0.464219115144888 units32_lr0.001
# 0.5719235586250605 units32_lr0.0001
# 0.4544688632454499 units64_lr0.1
# 0.4559669656875608 units64_lr0.01
# 0.46332374104729845 units64_lr0.001
# 0.5712900735762445 units64_lr0.0001

# %%
uoro_results = get_task_results(mypath ='../cluster_results/uoro_test/')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-9-89a9344ae111> in <module>
# ----> 1 uoro_results = get_task_results(mypath ='../cluster_results/uoro_test/')
#
# <ipython-input-2-fe20b26a279c> in get_task_results(mypath)
#       1 def get_task_results(mypath):
# ----> 2     onlyfiles = [f for f in listdir(mypath) if isfile(join(mypath, f))]
#       3     if '.DS_Store' in onlyfiles:
#       4         onlyfiles.remove('.DS_Store')
#       5     sorted = onlyfiles.sort(key=lambda x:int(x.split('_')[1]))
#
# FileNotFoundError: [Errno 2] No such file or directory: '../cluster_results/uoro_test/'

# %%
fig, axs = plt.subplots(2, 2,figsize=(20,10))

for r in uoro_results:
    avg_loss = r['average_loss']

    if r['config']['lr'] == 0.001:
        legend = 'units{}_lr{}'.format(r['config']['units'],r['config']['lr'])
        axs[0, 0].plot(avg_loss, label =legend)
    axs[0, 0].legend()
    axs[0, 0].set_ylim(0.4,0.8)
    axs[0, 0].set_title('UORO LSTM Average Loss')
    
    if r['config']['lr'] == 0.0001:
        legend = 'units{}_lr{}'.format(r['config']['units'],r['config']['lr'])
        axs[0, 1].plot(avg_loss,label = legend)
    axs[0, 1].legend()
    axs[0, 1].set_ylim(0.4,0.8)
    axs[0, 1].set_title('UORO LSTM Average Loss')

    if r['config']['lr'] == 0.00001:
        legend = 'units{}_lr{}'.format(r['config']['units'],r['config']['lr'])
        axs[1, 0].plot(avg_loss,label=legend)        
    axs[1, 0].legend()
    axs[1, 0].set_ylim(0.4,0.8)
    axs[1, 0].set_title('UORO LSTM Average Loss')
    print(min(avg_loss),legend)
# Out:
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.

# %%
kf_results = get_task_results(mypath ='../cluster_results/kf_sgd/')

# %%
fig, axs = plt.subplots(2, 2,figsize=(20,10))

for r in kf_results:
    avg_loss = r['average_loss']

    if r['config']['lr'] == 0.1:
        legend = 'units{}_lr{}'.format(r['config']['units'],r['config']['lr'])
        axs[0, 0].plot(avg_loss, label =legend)
    axs[0, 0].legend()
    axs[0, 0].set_ylim(0.4,0.8)
    axs[0, 0].set_title('KF LSTM Average Loss')
    
    if r['config']['lr'] == 0.01:
        legend = 'units{}_lr{}'.format(r['config']['units'],r['config']['lr'])
        axs[0, 1].plot(avg_loss,label = legend)
    axs[0, 1].legend()
    axs[0, 1].set_ylim(0.4,0.8)
    axs[0, 1].set_title('KF LSTM Average Loss')

    if r['config']['lr'] == 0.01:
        legend = 'units{}_lr{}'.format(r['config']['units'],r['config']['lr'])
        axs[1, 0].plot(avg_loss,label=legend)        
    axs[1, 0].legend()
    axs[1, 0].set_ylim(0.4,0.8)
    axs[1, 0].set_title('KF LSTM Average Loss')

    if r['config']['lr'] == 0.001:
        legend = 'units{}_lr{}'.format(r['config']['units'],r['config']['lr'])
        axs[1, 1].plot(avg_loss,label =legend)       
    axs[1, 1].legend()
    axs[1, 1].set_ylim(0.4,0.8)
    axs[1, 1].set_title('KF LSTM Average Loss')

    print(min(avg_loss),legend)
# Out:
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# 0.5601758964518861 units8_lr0.01
# 0.5364512409907894 units8_lr0.001
# 0.48150795304363103 units16_lr0.01
# 0.48360509815072616 units16_lr0.001
# 0.4604596749595883 units32_lr0.01
# 0.51986175835248 units32_lr0.001

# %%
FBPTT_results = get_task_results(mypath ='../cluster_results/FBPTT_test/')

# %%
fig, axs = plt.subplots(2, 2,figsize=(20,10))

for r in FBPTT_results:
    avg_loss = r['average_loss']
    
    if r['config']['T'] == 30:
        legend = 'units{}_beta{}_T{}'.format(r['config']['units'],r['config']['beta'],r['config']['T'])
        axs[0, 0].plot(avg_loss, label =legend)
    axs[0, 0].legend()
    axs[0, 0].set_ylim(0.4,0.8)
    axs[0, 0].set_title('FBPTT LSTM Average Loss')
    
    if r['config']['T'] == 40:
        legend = 'units{}_beta{}_T{}'.format(r['config']['units'],r['config']['beta'],r['config']['T'])
        axs[0, 1].plot(avg_loss,label = legend)
    axs[0, 1].legend()
    axs[0, 1].set_ylim(0.4,0.8)
    axs[0, 1].set_title('FBPTT LSTM Average Loss')

    if r['config']['T'] == 50:
        legend = 'units{}_beta{}_T{}'.format(r['config']['units'],r['config']['beta'],r['config']['T'])
        axs[1, 0].plot(avg_loss,label=legend)        
    axs[1, 0].legend()
    axs[1, 0].set_ylim(0.4,0.8)
    axs[1, 0].set_title('FBPTT LSTM Average Loss')

    if r['config']['T'] == 60:
        legend = 'units{}_beta{}_T{}'.format(r['config']['units'],r['config']['beta'],r['config']['T'])
        axs[1, 1].plot(avg_loss,label =legend)       
    axs[1, 1].legend()
    axs[1, 1].set_ylim(0.4,0.8)
    axs[1, 1].set_title('FBPTT LSTM Average Loss')
    print(min(avg_loss),legend)
# Out:
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# 0.5060385447555965 units32_beta0.9_T30
# 0.524718983435596 units32_beta0.9_T40
# 0.48948685202939113 units32_beta0.9_T50
# 0.4995336496065829 units32_beta0.9_T60
# 0.5029050934709353 units32_beta0.8_T30
# 0.4854614049513973 units32_beta0.8_T40
# 0.4775430571710162 units64_beta0.9_T40
# 0.4648509035613973 units64_beta0.9_T50
# 0.4708811230563092 units64_beta0.9_T60
# 0.4697229746106737 units64_beta0.8_T30
# 0.4769892523597592 units64_beta0.8_T40
# 0.46337662819551245 units64_beta0.8_T50
# 0.4686319383061086 units64_beta0.8_T60

# %%
EBPTT_adam_results = get_task_results(mypath ='../cluster_results/EBPTT_less_adam/')

# %%
fig, axs = plt.subplots(2, 2,figsize=(20,10))
for r in EBPTT_adam_results:
    avg_loss = r['average_loss']

    if r['config']['lr'] == 0.001 and r['config']['beta'] == 0.8:
        legend = 'units{}_lr{}_{}_T{}'.format(r['config']['units'],r['config']['lr'],r['config']['beta'],r['config']['T'])
        axs[0, 0].plot(avg_loss, label =legend)
    axs[0, 0].legend()
    axs[0, 0].set_ylim(0.4,0.8)
    axs[0, 0].set_title('EBPTT LSTM Average Loss')
    
    if r['config']['lr'] == 0.001 and r['config']['beta'] == 0.9:
        legend = 'units{}_lr{}_{}_T{}'.format(r['config']['units'],r['config']['lr'],r['config']['beta'],r['config']['T'])
        axs[0, 1].plot(avg_loss,label = legend)
    axs[0, 1].legend()
    axs[0, 1].set_ylim(0.4,0.8)
    axs[0, 1].set_title('EBPTT LSTM Average Loss')

    if r['config']['lr'] == 0.0001 and r['config']['beta'] == 0.8:
        legend = 'units{}_lr{}_{}_T{}'.format(r['config']['units'],r['config']['lr'],r['config']['beta'],r['config']['T'])
        axs[1, 0].plot(avg_loss,label=legend)        
    axs[1, 0].legend()
    axs[1, 0].set_ylim(0.4,0.8)
    axs[1, 0].set_title('EBPTT LSTM Average Loss')

    if r['config']['lr'] == 0.0001 and r['config']['beta'] == 0.9:
        legend = 'units{}_lr{}_{}_T{}'.format(r['config']['units'],r['config']['lr'],r['config']['beta'],r['config']['T'])
        axs[1, 1].plot(avg_loss,label =legend)       
    axs[1, 1].legend()
    axs[1, 1].set_ylim(0.4,0.8)
    axs[1, 1].set_title('EBPTT LSTM Average Loss')
    print(min(avg_loss),legend)
# Out:
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# 0.5244756043768986 units32_lr0.001_0.9_T30
# 0.4882299825776951 units32_lr0.001_0.8_T30
# 0.4979762396835813 units32_lr0.001_0.9_T40
# 0.4981637280507573 units32_lr0.001_0.8_T40
# 0.4925578632560682 units32_lr0.001_0.9_T50
# 0.4900461476090093 units32_lr0.001_0.8_T50
# ...

# %%
BPTT_results = get_task_results(mypath ='../cluster_results/BPTT/')

# %%
fig, axs = plt.subplots(2, 2,figsize=(20,10))

for r in BPTT_results:
    avg_loss = r['average_loss']
    
    if r['config']['T'] == 10:
        legend = 'lr{}_{}_units{}'.format(r['config']['lr'],r['config']['algorithm'],r['config']['units'])
        axs[0, 0].plot(avg_loss, label =legend)
    axs[0, 0].legend()
    axs[0, 0].set_ylim(0.4,0.8)
    axs[0, 0].set_title('Easy UORO LSTM Average Loss unit64')
    
    if r['config']['T'] == 20:
        legend = 'lr{}_{}_T{}'.format(r['config']['lr'],r['config']['algorithm'],r['config']['units'])
        axs[0, 1].plot(avg_loss,label = legend)
    axs[0, 1].legend()
    axs[0, 1].set_ylim(0.4,0.8)
    axs[0, 1].set_title('BPTT LSTM Average Loss unit64')

    if r['config']['T'] == 30:
        legend = 'lr{}_{}_T{}'.format(r['config']['lr'],r['config']['algorithm'],r['config']['units'])
        axs[1, 0].plot(avg_loss,label=legend)        
    axs[1, 0].legend()
    axs[1, 0].set_ylim(0.4,0.8)
    axs[1, 0].set_title('BPTT LSTM Average Loss unit64')

    if r['config']['T'] == 40:
        legend = 'lr{}_{}_T{}'.format(r['config']['lr'],r['config']['algorithm'],r['config']['units'])
        axs[1, 1].plot(avg_loss,label =legend)       
    axs[1, 1].legend()
    axs[1, 1].set_ylim(0.4,0.8)
    axs[1, 1].set_title('BPTT LSTM Average Loss unit64')
    print(min(avg_loss),legend)
# Out:
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# 0.526956717965004 lr0.1_E-BPTT_units64
# 0.5153024391370956 lr0.1_E-BPTT_T64
# 0.5172678702382509 lr0.1_E-BPTT_T64
# 0.5171686205038731 lr0.1_E-BPTT_T64
# 0.5727238135373196 lr0.1_F-BPTT_units64
# 0.47452226908227224 lr0.1_F-BPTT_T64
# 0.5174297866930929 lr0.1_F-BPTT_T64
# 0.481637244807255 lr0.1_F-BPTT_T64

# %%
hard_results = get_task_results(mypath ='../cluster_results/uoro_kf_SGD/')

# %%
fig, axs = plt.subplots(2, 2,figsize=(20,10))

for r in hard_results:
    avg_loss = r['average_loss']

    if r['config']['algorithm']=='uoro':
        legend = 'units{}_lr{}_{}'.format(r['config']['units'],r['config']['lr'],r['config']['algorithm'])
        axs[0, 0].plot(avg_loss, label =legend)
    axs[0, 0].legend()
    axs[0, 0].set_ylim(0.4,0.8)
    axs[0, 0].set_title('KF LSTM Average Loss')
    
    if r['config']['algorithm']=='uoro':
        legend = 'units{}_lr{}_{}'.format(r['config']['units'],r['config']['lr'],r['config']['algorithm'])
        axs[0, 1].plot(avg_loss,label = legend)
    axs[0, 1].legend()
    axs[0, 1].set_ylim(0.4,0.8)
    axs[0, 1].set_title('KF LSTM Average Loss')

    if r['config']['algorithm']=='kf':
        legend = 'units{}_lr{}_{}'.format(r['config']['units'],r['config']['lr'],r['config']['algorithm'])
        axs[1, 0].plot(avg_loss,label=legend)        
    axs[1, 0].legend()
    axs[1, 0].set_ylim(0.4,0.8)
    axs[1, 0].set_title('KF LSTM Average Loss')

    if r['config']['algorithm']=='kf':
        legend = 'units{}_lr{}_{}'.format(r['config']['units'],r['config']['lr'],r['config']['algorithm'])
        axs[1, 1].plot(avg_loss,label =legend)       
    axs[1, 1].legend()
    axs[1, 1].set_ylim(0.4,0.8)
    axs[1, 1].set_title('KF LSTM Average Loss')
    print(min(avg_loss),legend)
# Out:
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# nan units32_lr0.01_uoro
# 0.6499337836312373 units32_lr0.01_kf
# 0.6098943854911943 units32_lr0.001_uoro
# 0.6371434769167343 units32_lr0.001_kf
# 0.5734356641849285 units32_lr0.0001_uoro
# 0.6344078881460902 units32_lr0.0001_kf
# 0.6439006548191039 units64_lr0.01_kf
# 0.6260971056846728 units64_lr0.001_kf
# 0.623716509947503 units64_lr0.0001_kf
# 0.6484115362125167 units128_lr0.01_kf
# 0.6213456177129972 units128_lr0.001_kf
# 0.6185330252439741 units128_lr0.0001_kf

# %%
uoro_easy = get_task_results(mypath ='../cluster_results/BPTT/')

# %%
fig, axs = plt.subplots(2, 2,figsize=(20,10))

for r in uoro_easy:
    avg_loss = r['average_loss']

    if r['config']['T'] == 10:
        legend = 'units{}_lr{}_{}'.format(r['config']['units'],r['config']['lr'],r['config']['beta'])
        axs[0, 0].plot(avg_loss, label =legend)
    axs[0, 0].legend()
    axs[0, 0].set_ylim(0.4,0.8)
    axs[0, 0].set_title('UORO LSTM Average Loss')
    
    if r['config']['lr'] == 0.0001:
        legend = 'units{}_lr{}_{}'.format(r['config']['units'],r['config']['lr'],r['config']['beta'])
        axs[0, 1].plot(avg_loss,label = legend)
    axs[0, 1].legend()
    axs[0, 1].set_ylim(0.4,0.8)
    axs[0, 1].set_title('UORO LSTM Average Loss')

    if r['config']['lr'] == 0.00001:
        legend = 'units{}_lr{}_{}'.format(r['config']['units'],r['config']['lr'],r['config']['beta'])
        axs[1, 0].plot(avg_loss,label=legend)        
    axs[1, 0].legend()
    axs[1, 0].set_ylim(0.4,0.8)
    axs[1, 0].set_title('UORO LSTM Average Loss')
    print(min(avg_loss),legend)
# Out:
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# 0.46044396995171594 units8_lr0.001_0.9
# 0.4549121888539309 units16_lr0.001_0.9
