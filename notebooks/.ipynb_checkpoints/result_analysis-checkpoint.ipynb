# %%
import sys
sys.path.append('../')
from simulation import Simulation
from os import listdir
from os.path import isfile, join
import pickle
import matplotlib.pyplot as plt

# %%
def get_task_results(mypath):
    onlyfiles = [f for f in listdir(mypath) if isfile(join(mypath, f))]
    if '.DS_Store' in onlyfiles:
        onlyfiles.remove('.DS_Store')
    sorted = onlyfiles.sort(key=lambda x:int(x.split('_')[1]))
    onlyfiles.sort(key=lambda x:int(x.split('_')[1]))
    results = []
    for i in onlyfiles:
        results.append(pickle.load(open(join(mypath,i),'rb')))
    return results

def visualization(results,title = 'LSTM Average Loss',legend_list=['units','lr'],split_by='lr',split_value=[0.1,0.01,0.001,0.0001]):
    fig, axs = plt.subplots(2, 2,figsize=(20,10))
    for r in results:
        avg_loss = r['average_loss']
        if r['config'][split_by] == split_value[0]:
            legend = '_'.join(['{}{}'.format(i,r['config'][i]) for i in legend_list])
            axs[0, 0].plot(avg_loss, label =legend)
        axs[0, 0].legend()
        axs[0, 0].set_ylim(0.4,0.8)
        axs[0, 0].set_title(title)

        if r['config'][split_by] == split_value[1]:
            legend = '_'.join(['{}{}'.format(i,r['config'][i]) for i in legend_list])
            axs[0, 1].plot(avg_loss,label = legend)
        axs[0, 1].legend()
        axs[0, 1].set_ylim(0.4,0.8)
        axs[0, 1].set_title(title)

        if r['config'][split_by] == split_value[2]:
            legend = '_'.join(['{}{}'.format(i,r['config'][i]) for i in legend_list])
            axs[1, 0].plot(avg_loss,label=legend)        
        axs[1, 0].legend()
        axs[1, 0].set_ylim(0.4,0.8)
        axs[1, 0].set_title(title)

        if r['config'][split_by] == split_value[3]:
            legend = '_'.join(['{}{}'.format(i,r['config'][i]) for i in legend_list])
            axs[1, 1].plot(avg_loss,label =legend)       
        axs[1, 1].legend()
        axs[1, 1].set_ylim(0.4,0.8)
        axs[1, 1].set_title(title)

        print(min(avg_loss),legend)

# %%
rtrl_results = get_task_results(mypath ='../../cluster_results/rtrl_test/')
visualization(rtrl_results,title = 'RTRL LSTM Average Loss',legend_list=['units','lr'],split_by='lr',split_value=[0.1,0.01,0.001,0.0001])
# Out:
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# 0.5123537138237984 units8_lr0.1
# 0.48525035828180524 units8_lr0.01
# 0.48399476702747146 units8_lr0.001
# 0.58056438313172 units8_lr0.0001
# 0.4696077705369018 units16_lr0.1
# 0.45817818966804275 units16_lr0.01
# 0.46246268131717144 units16_lr0.001
# 0.5739633132386046 units16_lr0.0001
# 0.45821640581484957 units32_lr0.1
# 0.4551494789559253 units32_lr0.01
# 0.464219115144888 units32_lr0.001
# 0.5719235586250605 units32_lr0.0001
# 0.4544688632454499 units64_lr0.1
# 0.4559669656875608 units64_lr0.01
# 0.46332374104729845 units64_lr0.001
# 0.5712900735762445 units64_lr0.0001

# %%
kf_results = get_task_results(mypath ='../../cluster_results/kf_adam/')
visualization(kf_results,title = 'KF_adam LSTM Average Loss',legend_list=['units','lr'],split_by='lr',split_value=[0.001,0.0005,0,1])
# Out:
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# 0.5567310528467714 units8_lr0.001
# 0.52702775095967 units8_lr0.0005
# 0.49873870059706027 units16_lr0.001
# 0.47485577656672623 units16_lr0.0005
# 0.47927367503519624 units32_lr0.001
# 0.4723931376910541 units32_lr0.0005
# 0.4814022623133395
# ...

# %%
kf_sgd_results = get_task_results(mypath ='../../cluster_results/kf_sgd/')
visualization(kf_sgd_results,title = 'KF_sgd LSTM Average Loss',legend_list=['units','lr'],split_by='lr',split_value=[0.01,0.001,0.1,0.0001])
# Out:
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# 0.5601758964518861 units8_lr0.01
# 0.5364512409907894 units8_lr0.001
# 0.48150795304363103 units16_lr0.01
# 0.48360509815072616 units16_lr0.001
# ...

# %%
FBPTT_results = get_task_results(mypath ='../../cluster_results/FBPTT_test/')
visualization(FBPTT_results,title = 'FBPTT LSTM Average Loss',legend_list=['units','T','beta','lr'],split_by='T',split_value=[30,40,50,60])
# Out:
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# 0.5060385447555965 units32_T30_beta0.9_lr0.0001
# 0.524718983435596 units32_T40_beta0.9_lr0.0001
# 0.48948685202939113 units32_T50_beta0.9_lr0.0001
# 0.4995336496065829 units32_T60_beta0.9_lr0.0001
# 0.5029050934709353 units32_T30_beta0.8_lr0.0001
# 0.4854614049513973 units32_T40_beta0.8_lr0.0001
# 0.4775430571710162 units64_T40_beta0.9_lr0.0001
# 0.4648509035613973 units64_T50_beta0.9_lr0.0001
# 0.4708811230563092 units64_T60_beta0.9_lr0.0001
# 0.4697229746106737 units64_T30_beta0.8_lr0.0001
# 0.4769892523597592 units64_T40_beta0.8_lr0.0001
# 0.46337662819551245 units64_T50_beta0.8_lr0.0001
# 0.4686319383061086 units64_T60_beta0.8_lr0.0001

# %%
BPTT_results = get_task_results(mypath ='../../cluster_results/BPTT_SGD/')
visualization(BPTT_results,title = 'BPTT sgd LSTM Average Loss',legend_list=['algorithm','T','units','lr'],split_by='T',split_value=[20,30,40,50])
# Out:
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# 0.47129646226142646 algorithmF-BPTT_T20_units64_lr0.1
# 0.5257370826369953 algorithmF-BPTT_T30_units64_lr0.1
# 0.470553346399403 algorithmF-BPTT_T40_units64_lr0.1
# 0.47076097686031726 algorithmF-BPTT_T50_units64_lr0.1
# 0.46031841418347097 algorithmE-BPTT_T20_units64_lr0.1
# 0.464135355512115 algorithmE-BPTT_T30_units64_lr0.1
# 0.4589665484992905 algorithmE-BPTT_T40_units64_lr0.1
# 0.4653347202702469 algorithmE-BPTT_T50_units64_lr0.1
# 0.5558420738302129 algorithmF-BPTT_T20_units64_lr0.01
# 0.5559452020267082 algorithmF-BPTT_T30_units64_lr0.01
# 0.5559752964950653 algorithmF-BPTT_T40_units64_lr0.01
# 0.555827626601839 algorithmF-BPTT_T50_units64_lr0.01
# ...

# %%
uoro_easy = get_task_results(mypath ='../../cluster_results/uoro_easy_SGD/')
visualization(uoro_easy,title = 'UORO LSTM Average Loss',legend_list=['algorithm','units','lr'],split_by='lr')
# Out:
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# 0.46044396995172476 algorithmuoro_units8_lr0.001
# 0.454912188853931 algorithmuoro_units16_lr0.001
# 0.579195204482615 algorithmuoro_units32_lr0.001

# %%
uoro_results = get_task_results(mypath ='../cluster_results/uoro_test/')

# %%
fig, axs = plt.subplots(2, 2,figsize=(20,10))

for r in uoro_results:
    avg_loss = r['average_loss']

    if r['config']['lr'] == 0.001:
        legend = 'units{}_lr{}'.format(r['config']['units'],r['config']['lr'])
        axs[0, 0].plot(avg_loss, label =legend)
    axs[0, 0].legend()
    axs[0, 0].set_ylim(0.4,0.8)
    axs[0, 0].set_title('UORO LSTM Average Loss')
    
    if r['config']['lr'] == 0.0001:
        legend = 'units{}_lr{}'.format(r['config']['units'],r['config']['lr'])
        axs[0, 1].plot(avg_loss,label = legend)
    axs[0, 1].legend()
    axs[0, 1].set_ylim(0.4,0.8)
    axs[0, 1].set_title('UORO LSTM Average Loss')

    if r['config']['lr'] == 0.00001:
        legend = 'units{}_lr{}'.format(r['config']['units'],r['config']['lr'])
        axs[1, 0].plot(avg_loss,label=legend)        
    axs[1, 0].legend()
    axs[1, 0].set_ylim(0.4,0.8)
    axs[1, 0].set_title('UORO LSTM Average Loss')
    print(min(avg_loss),legend)
# Out:
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
